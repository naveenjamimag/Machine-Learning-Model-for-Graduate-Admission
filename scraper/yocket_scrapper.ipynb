# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
temp=[]


for i in range(1,15):
    page = requests.get("https://yocket.in/applications-admits-rejects/26228-null/2?page=" + str(i))

    soup = BeautifulSoup(page.content, 'html.parser')



    name_containers = soup.find_all('div', class_ = 'col-sm-6')
    for i in name_containers:
        k =(i.div.text)
        t=[i for i in k.strip().split("\n") if len(i) is not 0]
        temp.append(t)



r= pd.DataFrame(temp)

# %%
# !pip install selenium
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl
# ...

# %%
import pandas as pd
from selenium import webdriver
import time
from bs4 import BeautifulSoup

# %%
df_computer_Science_list_new = []
df_computer_science = pd.read_excel(r'computer_science_links_yocket.xlsx')
df_computer_science_list = df_computer_science['computer science'].tolist()

# %%
# !pip install fake_useragent
# Out:
# ...
#   Running setup.py bdist_wheel for fake-useragent: started
#   Running setup.py bdist_wheel for fake-useragent: finished with status 'done'
#   Stored in directory: C:\Users\navee\AppData\Local\pip\Cache\wheels\5e\63\09\d1dc15179f175357d3f5c00cbffbac37f9e8690d80545143ff
# Successfully built fake-useragent
# ...

# %%
for comp in df_computer_science_list:
    df_computer_Science_list_new.append(comp[:-1])
admits_rejects_links=[]
for i in df_computer_Science_list_new:
    admits_rejects_links.append(i+'2')
    admits_rejects_links.append(i+'3')
admits_rejects_links
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from fake_useragent import UserAgent

# %%
admits_rejects_links[60:]
# Out:
# ['https://yocket.in/applications-admits-rejects/183-purdue-university-west-lafayette/2',
#  'https://yocket.in/applications-admits-rejects/183-purdue-university-west-lafayette/3',
#  'https://yocket.in/applications-admits-rejects/394-university-of-california-davis/2',
#  'https://yocket.in/applications-admits-rejects/394-university-of-california-davis/3',
#  'https://yocket.in/applications-admits-rejects/168-university-of-southern-california/2',
#  'https://yocket.in/applications-admits-rejects/168-university-of-southern-california/3',
#  'https://yocket.in/applications-admits-rejects/31922-university-of-maryland-college-park/2',
#  'https://yocket.in/applications-admits-rejects/31922-university-of-maryland-college-park/3',
#  'https://yocket.in/applications-admits-rejects/59-university-of-california-santa-barbara/2',
#  'https://yocket.in/applications-admits-rejects/59-university-of-california-santa-barbara/3',
# ...

# %%
options = Options()
ua = UserAgent()
userAgent = ua.random

options.add_argument(f'user-agent={userAgent}')
driver = webdriver.Chrome(chrome_options=options, executable_path = 'chromedriver.exe')

driver.get('https://yocket.in/')
time.sleep(50)
for url in admits_rejects_links[60:80]:
    for i in range(1,4):
        driver.get(url + '?page=' + str(i))

       #page = requests.get("https://yocket.in/applications-admits-rejects/26228-null/2?page=" + str(i))
        html = driver.page_source
        soup = BeautifulSoup(html)
        name_containers = soup.find_all('div', class_ = 'col-sm-6')
        for i in name_containers:
            k =(i.div.text)
            t=[i for i in k.strip().split("\n") if len(i) is not 0]
            temp.append(t)
        time.sleep(15)
        r= pd.DataFrame(temp)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: use options instead of chrome_options

# %%
r.to_csv('6080.csv')

# %%
options = Options()
ua = UserAgent()
userAgent = ua.random

options.add_argument(f'user-agent={userAgent}')
driver = webdriver.Chrome(chrome_options=options, executable_path = 'chromedriver.exe')

driver.get('https://yocket.in/')
time.sleep(50)
for url in admits_rejects_links[80:101]:
    for i in range(1,4):
        driver.get(url + '?page=' + str(i))

       #page = requests.get("https://yocket.in/applications-admits-rejects/26228-null/2?page=" + str(i))
        html = driver.page_source
        soup = BeautifulSoup(html)
        name_containers = soup.find_all('div', class_ = 'col-sm-6')
        for i in name_containers:
            k =(i.div.text)
            t=[i for i in k.strip().split("\n") if len(i) is not 0]
            temp.append(t)
        time.sleep(15)
        r= pd.DataFrame(temp)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: use options instead of chrome_options

# %%
r.to_csv('80100.csv')

# %%
r.rename(columns={0: 'Name', 'newName2': 'University', 1: 'University', 2: 'Year', 3: 'Status',4: 'GRE',5: 'GRE_SCORE',6: 'Eng_test',7:'Test_score',8: 'Undergrad',9: 'Undergrad_score',11: 'work_ex'}, inplace=True)

# %%
r_copy = r
r=pd.read_csv('Final_sheet.csv')

# %%
r.drop(columns=['Unnamed: 0'],inplace=True)

# %%
r
# Out:
#                                    Name  \
# 0                     Welcome to Yocket
# 1                       VIEW ALL EVENTS
# 2          Q) What is Fast Track Event?
# 3                              sebsebin
# 4                              Whilmina
# 5                                 lisha
# 6                     chandrakanthyadav
# 7                           lalit_mohan
# 8                        AryaSrivastava
# 9                           Akshit_modi
# 10                             krupal97
# 11                                 WaiF
# 12                            Jinal3101
# 13                        priyankjethva
# 14                               VidyaV
# 15                            Palsin213
# 16                           kaivan1998
# 17                              sariska
# 18                       PruthviPatel96
# 19                              nidhijo
# 20                            ambar-roy
# 21                            shubhamla
# ...

# %%
r=r.loc[r['Name']!='Welcome to Yocket',:]

# %%
r=r.loc[r['Name']!='VIEW ALL EVENTS',:]

# %%
r=r.loc[r['Name']!='Q) What is Fast Track Event?',:]

# %%
r.University.value_counts()
# Out:
# University of California, San Diego Computer Science           660
# Stanford University Computer Science                           528
# University of Southern California Computer Science             478
# Purdue University West Lafayette Computer Science              454
# University of California, Davis Computer Science               396
# University of Maryland, College Park Computer Science          364
# Columbia University Computer Science                           360
# University of Wisconsin-Madison Computer Science               360
# University of California, Los Angeles Computer Science         360
# New York University Computer Science                           360
# University of California, Santa Barbara Computer Science       350
# University of Pennsylvania Computer & Information Science      324
# Cornell University Computer Science                            321
# Johns Hopkins University Computer Science                      288
# ...

# %%
r=r.drop_duplicates()

# %%
r=r.loc[r['Name']!='Fall 2019',:]

# %%
len(r.University.value_counts())
# Out:
# 70
