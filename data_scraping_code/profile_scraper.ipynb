# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from fake_useragent import UserAgent
from bs4 import BeautifulSoup
import re

# %%
student_admit_url=pd.read_excel('../Data/ALL PROFILES.xlsx')

# %%
student_admit_url.columns
# Out:
# Index(['carnegie-mellon-university_accept',
#        'carnegie-mellon-university_reject',
#        'Georgia Institute of technology_accept',
#        'Georgia Institute of technology_reject', 'Maryland_accept',
#        'Maryland_reject', 'university-of-california-irvine_accept',
#        'university-of-california-irvine_accept.1',
#        'university-of-colorado-boulder_accept',
#        'university-of-colorado-boulder_reject',
#        'texas-a-and-m-university-college-station_accept',
#        'texas-a-and-m-university-college-station_reject',
#        'state-university-of-new-york-at-stony-brook_accept',
#        'tate-university-of-new-york-at-stony-brook_reject',
#        'george-mason-university_accept', 'george-mason-university_reject',
#        'north-carolina-state-university-raleigh_accept',
#        'north-carolina-state-university-raleigh_reject',
#        'university-of-iowa_accept', 'university-of-iowa_reject',
# ...

# %%
carnegiemellonuniversity_reject=student_admit_url['university-of-iowa_accept'].dropna().tolist()

# %%
len(carnegiemellonuniversity_reject)
# Out:
# 57

# %%
name_containers6 = []

# %%
options = Options()
ua = UserAgent()
userAgent = ua.random

options.add_argument(f'user-agent={userAgent}')
driver = webdriver.Chrome(chrome_options=options, executable_path = '..\chrome_driver\chromedriver.exe')
i=1
time.sleep(5)
for each in carnegiemellonuniversity_reject:
    driver.get(each)
    i=i+1
    if i%5==0:
        options = Options()
        ua = UserAgent()
        userAgent = ua.random
        options.add_argument(f'user-agent={userAgent}')
        driver = webdriver.Chrome(chrome_options=options, executable_path = '..\chrome_driver\chromedriver.exe')
    if i%50==0:
        print('reached50')
        #time.sleep(100)
        
    html = driver.page_source
    soup = BeautifulSoup(html)
    name_containers6.append(soup.find_all('div', class_ = 'col-sm-4 col-xs-4'))
# Out:
# C:\Users\navee\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: use options instead of chrome_options
#
# C:\Users\navee\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: DeprecationWarning: use options instead of chrome_options
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ...

# %%
len(name_containers6)
# Out:
# 0

# %%
a = pd.DataFrame()
a['links'] = name_containers6
a['university_name'] = 'university of iowa'
a['status']='accept'

# %%
a
# Out:
#                                                  links  \
# 0    [<div class="col-sm-4 col-xs-4">
# <i class="fa ...
# 1    [<div class="col-sm-4 col-xs-4">
# <i class="fa ...
# 2    [<div class="col-sm-4 col-xs-4">
# <i class="fa ...
# 3                                                   []
# 4    [<div class="col-sm-4 col-xs-4">
# <i class="fa ...
# 5    [<div class="col-sm-4 col-xs-4">
# <i class="fa ...
# 6    [<div class="col-sm-4 col-xs-4">
# <i class="fa ...
# 7    [<div class="col-sm-4 col-xs-4">
# <i class="fa ...
# 8                                                   []
# 9    [<div class="col-sm-4 col-xs-4">
# <i class="fa ...
# 10   [<div class="col-sm-4 col-xs-4">
# <i class="fa ...
# 11   [<div class="col-sm-4 col-xs-4">
# <i class="fa ...
# 12   [<div class="col-sm-4 col-xs-4">
# <i class="fa ...
# 13                                                  []
# 14   [<div class="col-sm-4 col-xs-4">
# <i class="fa ...
# 15   [<div class="col-sm-4 col-xs-4">
# <i class="fa ...
# ...

# %%
a.to_csv('../Data/profile_data/stony_brook_reject.csv')

# %%
reject_data=[]
i=0
for each in profile_urls:
    i=i+1
    if i>1671:
        reject_data.append([each,'Reject'])

# %%
len(profile_urls)-len(reject_data)
# Out:
# 1671

# %%
reject_urls=[]
for each in reject_data:
    reject_urls.append(each[0])

# %%
student_reject_url=pd.DataFrame(reject_urls)

# %%
student_reject_url.to_csv('student_reject_url.csv')

# %%
students_all_url=student_admit_url.append(student_reject_url)

# %%
students_all_url[0]
# Out:
# 0                       https://yocket.in/profiles/ST1234
# 1                       https://yocket.in/profiles/ST1234
# 2               https://yocket.in/profiles/iamsudiptasaha
# 3                 https://yocket.in/profiles/HimanshuRock
# 4                        https://yocket.in/profiles/spell
# 5                      https://yocket.in/profiles/Munisum
# 6                 https://yocket.in/profiles/kavikalidasa
# 7                        https://yocket.in/profiles/LordM
# 8                  https://yocket.in/profiles/Aphrodite44
# 9                  https://yocket.in/profiles/darshan2018
# 10                   https://yocket.in/profiles/Gonemad97
# 11                    https://yocket.in/profiles/psahil19
# 12                     https://yocket.in/profiles/Uabs195
# 13                  https://yocket.in/profiles/loveToCode
# 14                 https://yocket.in/profiles/yashwanth96
# 15                     https://yocket.in/profiles/rajks20
# ...

# %%
student_admit_url=student_admit_url.drop_duplicates()
student_admit_url.reset_index(drop=True,inplace=True)

# %%
student_admit_url
# Out:
#                                                    0      1
# 0                  https://yocket.in/profiles/ST1234  Admit
# 1          https://yocket.in/profiles/iamsudiptasaha  Admit
# 2            https://yocket.in/profiles/HimanshuRock  Admit
# 3                   https://yocket.in/profiles/spell  Admit
# 4                 https://yocket.in/profiles/Munisum  Admit
# 5            https://yocket.in/profiles/kavikalidasa  Admit
# 6                   https://yocket.in/profiles/LordM  Admit
# 7             https://yocket.in/profiles/Aphrodite44  Admit
# 8             https://yocket.in/profiles/darshan2018  Admit
# 9               https://yocket.in/profiles/Gonemad97  Admit
# 10               https://yocket.in/profiles/psahil19  Admit
# 11                https://yocket.in/profiles/Uabs195  Admit
# 12             https://yocket.in/profiles/loveToCode  Admit
# 13            https://yocket.in/profiles/yashwanth96  Admit
# 14                https://yocket.in/profiles/rajks20  Admit
# ...

# %%
student_admit_url.to_csv('student_admit_url.csv')

# %%
for each in student_admit_url[0].tolist():
    print(each)
# Out:
# https://yocket.in/profiles/ST1234
# https://yocket.in/profiles/iamsudiptasaha
# https://yocket.in/profiles/HimanshuRock
# https://yocket.in/profiles/spell
# https://yocket.in/profiles/Munisum
# https://yocket.in/profiles/kavikalidasa
# https://yocket.in/profiles/LordM
# https://yocket.in/profiles/Aphrodite44
# https://yocket.in/profiles/darshan2018
# https://yocket.in/profiles/Gonemad97
# https://yocket.in/profiles/psahil19
# https://yocket.in/profiles/Uabs195
# https://yocket.in/profiles/loveToCode
# https://yocket.in/profiles/yashwanth96
# https://yocket.in/profiles/rajks20
# https://yocket.in/profiles/Summmm
# https://yocket.in/profiles/piyushms
# https://yocket.in/profiles/KSS1997
# https://yocket.in/profiles/damanamohana
# https://yocket.in/profiles/Shankar123
# https://yocket.in/profiles/aayush2641
# https://yocket.in/profiles/ketak1995
# https://yocket.in/profiles/SaishSankhe
# https://yocket.in/profiles/aishwarya34
# https://yocket.in/profiles/Snaiya
# ...

# %%
len(name_containers)
# Out:
# 195

# %%
len(name_containers1)
# Out:
# 155

# %%
len(name_containers2)
# Out:
# 65

# %%
len(name_containers3)
# Out:
# 204

# %%
len(name_containers)
# Out:
# 195

# %%
for each in [name_containers1,name_containers2,name_containers3]:
    for each1 in each:
        name_containers.append(each1)

# %%
for each in name_containers5:
    name_containers.append(each)

# %%
len(name_containers)
# Out:
# 791

# %%
df=pd.DataFrame()

# %%
df['html']=name_containers

# %%
df.to_csv('admit_data.csv')

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from fake_useragent import UserAgent
from bs4 import BeautifulSoup


options = Options()
ua = UserAgent()
userAgent = ua.random

options.add_argument(f'user-agent={userAgent}')
driver = webdriver.Chrome(chrome_options=options, executable_path = '..\chrome_driver\chromedriver.exe')
i=1
for each in student_admit_url[0].tolist()[619:]:
    driver.get(each)
    i=i+1
    if i%5==0:
        #time.sleep(10)
        options = Options()
        ua = UserAgent()
        userAgent = ua.random
        options.add_argument(f'user-agent={userAgent}')
        driver = webdriver.Chrome(chrome_options=options, executable_path = '..\chrome_driver\chromedriver.exe')
    if i%50==0:
        time.sleep(100)
        
    html = driver.page_source
    soup = BeautifulSoup(html)
    name_containers5.append(soup.find_all('div', class_ = 'col-sm-4 col-xs-4'))
# Out:
# C:\Users\navee\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: DeprecationWarning: use options instead of chrome_options
#   if sys.path[0] == '':
# C:\Users\navee\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: use options instead of chrome_options

# %%
temp = []
for each in range(0,1):
    for i in name_containers[each]:
        k = (i.h4.text)
        #print(k.text)
        #t=[i for i in k.strip().split("\n") if len(i) is not 0]
        print(k)
        temp.append(k)
print(len(temp))
# Out:
# GRE 316
#
# Quant: 164
# Verbal: 152
#
# TOEFL106
# UG Score
# 78%
#
# Work Exp.9 months
# Tech PapersInternational
# Dream Univ.USC
# 6

# %%
name_containers[0]
# Out:
# [<div class="col-sm-4 col-xs-4">
#  <i class="fa fa-globe fa-3x text-warning"></i>
#  <h4>
#  <small>GRE</small><br/> 316 <br/>
#  <span style="display:inline-block; line-height:1.5; font-size: 0.5em;">
#  Quant: 164<br/>
#  Verbal: 152 </span>
#  </h4>
#  </div>, <div class="col-sm-4 col-xs-4">
#  <i class="fa fa-book fa-3x text-warning"></i>
#  <h4><small>TOEFL</small><br/>106</h4>
#  </div>, <div class="col-sm-4 col-xs-4">
#  <i class="fa fa-graduation-cap fa-3x text-warning"></i>
#  <h4><small>UG Score</small><br/>
#  78%
#  </h4>
#  </div>, <div class="col-sm-4 col-xs-4">
#  <br/>
#  <i class="fa fa-briefcase fa-3x text-warning"></i>
#  <h4><small>Work Exp.</small><br/>9 months</h4>
#  </div>, <div class="col-sm-4 col-xs-4">
#  <br/>
#  <i class="fa fa-chart-line fa-3x text-warning"></i>
#  <h4><small>Tech Papers</small><br/>International</h4>
#  </div>, <div class="col-sm-4 col-xs-4">
#  <br/>
#  <i class="fa fa-university fa-3x text-warning"></i>
# ...

# %%
name_containers_rejects=[]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from fake_useragent import UserAgent
from bs4 import BeautifulSoup


options = Options()
ua = UserAgent()
userAgent = ua.random

options.add_argument(f'user-agent={userAgent}')
driver = webdriver.Chrome(chrome_options=options, executable_path = '..\chrome_driver\chromedriver.exe')
i=1
for each in student_admit_url[0].tolist()[416:]:
    driver.get(each)
    i=i+1
    if i%5==0:
        #time.sleep(10)
        options = Options()
        ua = UserAgent()
        userAgent = ua.random
        options.add_argument(f'user-agent={userAgent}')
        driver = webdriver.Chrome(chrome_options=options, executable_path = '..\chrome_driver\chromedriver.exe')
    if i%50==0:
        time.sleep(100)
        
    html = driver.page_source
    soup = BeautifulSoup(html)
    name_containers3.append(soup.find_all('div', class_ = 'col-sm-4 col-xs-4'))
