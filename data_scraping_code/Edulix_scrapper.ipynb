# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import pandas as pd
from selenium import webdriver
import time
from bs4 import BeautifulSoup
from selenium.webdriver.chrome.options import Options
from fake_useragent import UserAgent

# %% [markdown]
# ## University Data Scraping
#
# 1. Getting the links for 15 universities <br>
# 2. Scraping the data for Computer science deapartmant from Edulix website for the 15 Universities

# %%
temp1=[]

# %%
options = Options()
ua = UserAgent()
userAgent = ua.random

options.add_argument(f'user-agent={userAgent}')
driver = webdriver.Chrome(chrome_options=options, executable_path = 'chromedriver.exe')

driver.get('https://www.edulix.com/')
time.sleep(30)
driver.get('https://www.edulix.com/' + 'share-profile/93397')
#page = requests.get("https://yocket.in/applications-admits-rejects/26228-null/2?page=" + str(i))
html = driver.page_source
soup = BeautifulSoup(html)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: use options instead of chrome_options

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="csstransforms csstransforms3d csstransitions" lang="en" xmlns="http://www.w3.org/1999/xhtml"><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="6eFKuj45Huyrx5COSKwLdjt9QD9oqElOB14uGlvj" name="csrf-token"/>
# <link href="https://www.edulix.com/favicon.ico" rel="shortcut icon"/>
# <link href="https://www.edulix.com/css/app.css" rel="stylesheet"/>
# <link href="https://www.edulix.com/bootstrap-components/datepicker/bootstrap-datepicker.css" rel="stylesheet"/>
# <link href="https://www.edulix.com/css/bootstrap-social.css" rel="stylesheet"/>
# <link href="https://www.edulix.com/css/customStyles.css" rel="stylesheet"/>
# <link href="https://www.edulix.com/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="https://www.edulix.com/css/select2.min.css" rel="stylesheet"/>
# ...

# %%
name_containers = soup.select('.form-control-static')
name_containers
# Out:
# [<p class="form-control-static">girishpatni</p>,
#  <p class="form-control-static">Girish</p>,
#  <p class="form-control-static"></p>,
#  <p class="form-control-static"></p>,
#  <p class="form-control-static"></p>,
#  <p class="form-control-static"></p>,
#  <p class="form-control-static"></p>,
#  <p class="form-control-static"></p>,
#  <p class="form-control-static">NIT Patna</p>,
#  <p class="form-control-static">Computer Science</p>,
#  <p class="form-control-static">8.24/10</p>,
#  <p class="form-control-static"></p>,
#  <p class="form-control-static">167 /170</p>,
#  <p class="form-control-static">155 / 170</p>,
#  <p class="form-control-static">4 / 6</p>,
#  <p class="form-control-static">0000-00-00</p>,
#  <p class="form-control-static">0 / 30</p>,
#  <p class="form-control-static">0 / 30</p>,
#  <p class="form-control-static">0 / 30</p>,
#  <p class="form-control-static">0 / 30</p>,
#  <p class="form-control-static">0000-00-00</p>,
#  <p class="form-control-static">0 / 9</p>,
# ...

# %%
for i in name_containers:
    k =(i.text)
    t=[i for i in k.strip().split("\n") if len(i) is not 0]
    temp1.append(t)
    #time.sleep(15)
r1= pd.DataFrame(temp1)

# %%
name_containers[0].text
# Out:
# 'girishpatni'

# %%
naveenj11695@gmail.com

# %%
options = Options()
ua = UserAgent()
userAgent = ua.random

options.add_argument(f'user-agent={userAgent}')
driver = webdriver.Chrome(chrome_options=options, executable_path = 'chromedriver.exe')

driver.get('https://www.edulix.com/')
time.sleep(30)
driver.get('https://www.edulix.com/' + 'student-profiles')
time.sleep(50)
#page = requests.get("https://yocket.in/applications-admits-rejects/26228-null/2?page=" + str(i))
html = driver.page_source
soup = BeautifulSoup(html)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: use options instead of chrome_options

# %%
url_containers = soup.select('#jqGrid')
url_containers
# Out:
# [<table aria-labelledby="gbox_jqGrid" aria-multiselectable="false" border="0" cellpadding="0" cellspacing="0" class="table ui-jqgrid-btable" id="jqGrid" role="grid" style="width: 999px;" tabindex="0"><tbody><tr class="jqgfirstrow" role="row" style="height:auto"><td role="gridcell" style="height:0px;width:107px;"></td><td role="gridcell" style="height:0px;width:214px;"></td><td role="gridcell" style="height:0px;width:71px;"></td><td role="gridcell" style="height:0px;width:71px;"></td><td role="gridcell" style="height:0px;width:71px;"></td><td role="gridcell" style="height:0px;width:93px;"></td><td role="gridcell" style="height:0px;width:214px;"></td><td role="gridcell" style="height:0px;width:86px;"></td><td role="gridcell" style="height:0px;width:72px;"></td></tr><tr class="ui-widget-content jqgrow ui-row-ltr" id="1" role="row" tabindex="-1"><td aria-describedby="jqGrid_user_id" role="gridcell" style="text-align:center;" title="View Profile"><a href="/share-profile/51243" style="colo
# ...

# %%
profiles=[]
for i in url_containers[0].find_all("a", href=True):
    print(i['href'])
# Out:
# /share-profile/51243
# /share-profile/60418
# /share-profile/70921
# /share-profile/71696
# /share-profile/75778
# /share-profile/75786
# /share-profile/82435
# /share-profile/83359
# /share-profile/85497
# /share-profile/86456
# /share-profile/87421
# /share-profile/89467
# /share-profile/93397
# /share-profile/101376
# /share-profile/103171
# /share-profile/105929
# /share-profile/107990
# /share-profile/109798
# /share-profile/111411
# /share-profile/112977
# /share-profile/113399
# /share-profile/116676
# /share-profile/120608
# /share-profile/121989
# /share-profile/124203
# /share-profile/124869
# /share-profile/125624
# /share-profile/125663
# /share-profile/125670
# /share-profile/126794

# %%
find_jobs = driver.find_element_by_xpath(r'//*[@id="next_jqGridPager"]/span')
driver.execute_script('arguments[0].click();',find_jobs)
html1 = driver.page_source
soup = BeautifulSoup(html1)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="csstransforms csstransforms3d csstransitions" lang="en" xmlns="http://www.w3.org/1999/xhtml"><head>
# <title>Student Profile Search</title>
# <meta content="View profiles of students who got admitted to, applied or planning to apply to various universities. This helps your compare your profile to theirs." name="description"/>
# <meta content="MS in US, student, profiles, similar, compare, admitted, planning to apply, rejected, universities" name="keywords"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="r6z3cyIdHn9SQReu3cIuxpPAzvRlQ0xELDFyiGH7" name="csrf-token"/>
# <link href="https://www.edulix.com/favicon.ico" rel="shortcut icon"/>
# <link href="https://www.edulix.com/css/app.css" rel="stylesheet"/>
# <link href="https://www.edulix.com/bootstrap-components/datepicker/bootstrap-datepicker.css" rel="stylesheet"/>
# ...

# %%
url_containers = soup.select('#jqGrid')
url_containers
# Out:
# [<table aria-labelledby="gbox_jqGrid" aria-multiselectable="false" border="0" cellpadding="0" cellspacing="0" class="table ui-jqgrid-btable" id="jqGrid" role="grid" style="width: 999px;" tabindex="0"><tbody><tr class="jqgfirstrow" role="row" style="height:auto"><td role="gridcell" style="height:0px;width:107px;"></td><td role="gridcell" style="height:0px;width:214px;"></td><td role="gridcell" style="height:0px;width:71px;"></td><td role="gridcell" style="height:0px;width:71px;"></td><td role="gridcell" style="height:0px;width:71px;"></td><td role="gridcell" style="height:0px;width:93px;"></td><td role="gridcell" style="height:0px;width:214px;"></td><td role="gridcell" style="height:0px;width:86px;"></td><td role="gridcell" style="height:0px;width:72px;"></td></tr><tr class="ui-widget-content jqgrow ui-row-ltr" id="61" role="row" tabindex="-1"><td aria-describedby="jqGrid_user_id" role="gridcell" style="text-align:center;" title="View Profile"><a href="/share-profile/144637" style="co
# ...

# %%
profiles=[]
for i in url_containers[0].find_all("a", href=True):
    print(i['href'])
# Out:
# /share-profile/144637
# /share-profile/144671
# /share-profile/146258
# /share-profile/146598
# /share-profile/146980
# /share-profile/147221
# /share-profile/148111
# /share-profile/148446
# /share-profile/148512
# /share-profile/148919
# /share-profile/149006
# /share-profile/150166
# /share-profile/151139
# /share-profile/151245
# /share-profile/152063
# /share-profile/152775
# /share-profile/153437
# /share-profile/153612
# /share-profile/153636
# /share-profile/153707
# /share-profile/153866
# /share-profile/154143
# /share-profile/154145
# /share-profile/154476
# /share-profile/154690
# /share-profile/155114
# /share-profile/155433
# /share-profile/155549
# /share-profile/156261
# /share-profile/156286

# %%
def get_student_profile_urls():
    options = Options()
    ua = UserAgent()
    userAgent = ua.random
    options.add_argument(f'user-agent={userAgent}')
    driver = webdriver.Chrome(chrome_options=options, executable_path = 'chromedriver.exe')
    driver.get('https://www.edulix.com/')
    time.sleep(50)
    driver.get('https://www.edulix.com/' + 'student-profiles')
    time.sleep(50)
    #page = requests.get("https://yocket.in/applications-admits-rejects/26228-null/2?page=" + str(i))
    profile_urls = []
    for i in range(1,19):
        html = driver.page_source
        soup = BeautifulSoup(html)
        url_containers = soup.select('#jqGrid')
        for i in url_containers[0].find_all("a", href=True):
            profile_urls.append("https://www.edulix.com"+i['href'])
        find_profiles = driver.find_element_by_xpath(r'//*[@id="next_jqGridPager"]/span')
        driver.execute_script('arguments[0].click();',find_profiles)
    return profile_urls

# %%
#naveenj11695@gmail.com
neu_profiles = get_student_profile_urls()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: use options instead of chrome_options

# %%
neu_profiles_df = pd.DataFrame({"profiles":neu_profiles})

# %%
neu_profiles_df.to_csv("neu_profiles_df.csv")

# %%
asu_profiles = get_student_profile_urls()
asu_profiles_df = pd.DataFrame({"profiles":asu_profiles})
asu_profiles_df.to_csv("asu_profiles_df.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: use options instead of chrome_options

# %%
asu_profiles = get_student_profile_urls()
asu_profiles_df = pd.DataFrame({"profiles":asu_profiles})
asu_profiles_df.to_csv("asu_profiles_df.csv")

# %%
len(asu_profiles)
# Out:
# 1346

# %%
iitc_profiles = get_student_profile_urls()
iitc_profiles_df = pd.DataFrame({"profiles":iitc_profiles})
iitc_profiles_df.to_csv("iitc_profiles_df.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: use options instead of chrome_options

# %%
len(iitc_profiles)
# Out:
# 387

# %%
#naveenj11695@gmail.com
syracuse_profiles = get_student_profile_urls()
syracuse_profiles_df = pd.DataFrame({"profiles":syracuse_profiles})
syracuse_profiles_df.to_csv("syracuse_profiles_df.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: use options instead of chrome_options

# %%
len(syracuse_profiles)
# Out:
# 466

# %%
utd_profiles = get_student_profile_urls()
utd_profiles_df = pd.DataFrame({"profiles":utd_profiles})
utd_profiles_df.to_csv("utd_profiles_df.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: use options instead of chrome_options

# %%
len(utd_profiles)
# Out:
# 1470

# %%
uta_profiles = get_student_profile_urls()
uta_profiles_df = pd.DataFrame({"profiles":uta_profiles})
uta_profiles_df.to_csv("uta_profiles_df.csv")
len(uta_profiles)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: use options instead of chrome_options
# 489

# %%
#naveenj11695@gmail.com
clemson_profiles = get_student_profile_urls()
clemson_profiles_df = pd.DataFrame({"profiles":clemson_profiles})
clemson_profiles_df.to_csv("clemson_profiles_df.csv")
len(clemson_profiles)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: use options instead of chrome_options
# 199

# %%
#naveenj11695@gmail.com
rit_profiles = get_student_profile_urls()
rit_profiles_df = pd.DataFrame({"profiles":rit_profiles})
rit_profiles_df.to_csv("rit_profiles_df.csv")
len(rit_profiles)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: use options instead of chrome_options
# 561

# %%
#naveenj11695@gmail.com
usc_profiles = get_student_profile_urls()
usc_profiles_df = pd.DataFrame({"profiles":usc_profiles})
usc_profiles_df.to_csv("usc_profiles_df.csv")

# %%
len(usc_profiles)
# Out:
# 730

# %%
#naveenj11695@gmail.com
mtu_profiles = get_student_profile_urls()
mtu_profiles_df = pd.DataFrame({"profiles":mtu_profiles})
mtu_profiles_df.to_csv("mtu_profiles_df.csv")
len(mtu_profiles)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: use options instead of chrome_options
# 291

# %%
#naveenj11695@gmail.com
nyu_profiles = get_student_profile_urls()
nyu_profiles_df = pd.DataFrame({"profiles":nyu_profiles})
nyu_profiles_df.to_csv("nyu_profiles_df.csv")
len(nyu_profiles)
# Out:
# 158

# %%
#naveenj11695@gmail.com
iub_profiles = get_student_profile_urls()
iub_profiles_df = pd.DataFrame({"profiles":iub_profiles})
iub_profiles_df.to_csv("iub_profiles_df.csv")
len(iub_profiles)
# Out:
# 310

# %%
#naveenj11695@gmail.com
rutgers_profiles = get_student_profile_urls()
rutgers_profiles_df = pd.DataFrame({"profiles":rutgers_profiles})
rutgers_profiles_df.to_csv("rutgers_profiles_df.csv")
len(rutgers_profiles)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: use options instead of chrome_options
# 133

# %%
#naveenj11695@gmail.com
sjsu_profiles = get_student_profile_urls()
sjsu_profiles_df = pd.DataFrame({"profiles":sjsu_profiles})
sjsu_profiles_df.to_csv("sjsu_profiles_df.csv")
len(sjsu_profiles_df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: use options instead of chrome_options
# 378

# %%
#naveenj11695@gmail.com
ufl_profiles = get_student_profile_urls()
ufl_profiles_df = pd.DataFrame({"profiles":ufl_profiles})
ufl_profiles_df.to_csv("ufl_profiles_df.csv")
len(ufl_profiles_df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: use options instead of chrome_options
# 534

# %%
total_profiles_urls = neu_profiles_df.append(asu_profiles_df).append(iitc_profiles_df).append(syracuse_profiles_df).append(utd_profiles_df).append(uta_profiles_df).append(clemson_profiles_df).append(rit_profiles_df).append(usc_profiles_df).append(mtu_profiles_df).append(nyu_profiles_df).append(iub_profiles_df).append(rutgers_profiles_df).append(sjsu_profiles_df).append(ufl_profiles_df)

# %%
total_profiles_urls.reset_index(drop=True,inplace=True)

# %%
total_profiles_urls
# Out:
#                                          profiles
# 0      https://www.edulix.com/share-profile/51243
# 1      https://www.edulix.com/share-profile/60418
# 2      https://www.edulix.com/share-profile/70921
# 3      https://www.edulix.com/share-profile/71696
# 4      https://www.edulix.com/share-profile/75778
# 5      https://www.edulix.com/share-profile/75786
# 6      https://www.edulix.com/share-profile/82435
# 7      https://www.edulix.com/share-profile/83359
# 8      https://www.edulix.com/share-profile/85497
# 9      https://www.edulix.com/share-profile/86456
# 10     https://www.edulix.com/share-profile/87421
# 11     https://www.edulix.com/share-profile/89467
# 12     https://www.edulix.com/share-profile/93397
# 13    https://www.edulix.com/share-profile/101376
# 14    https://www.edulix.com/share-profile/103171
# 15    https://www.edulix.com/share-profile/105929
# 16    https://www.edulix.com/share-profile/107990
# 17    https://www.edulix.com/share-profile/109798
# ...

# %%
total_profiles_urls=total_profiles_urls.drop_duplicates()

# %%
total_profiles_urls.reset_index(drop=True,inplace=True)

# %%
total_profiles_urls
# Out:
#                                          profiles
# 0      https://www.edulix.com/share-profile/51243
# 1      https://www.edulix.com/share-profile/60418
# 2      https://www.edulix.com/share-profile/70921
# 3      https://www.edulix.com/share-profile/71696
# 4      https://www.edulix.com/share-profile/75778
# 5      https://www.edulix.com/share-profile/75786
# 6      https://www.edulix.com/share-profile/82435
# 7      https://www.edulix.com/share-profile/83359
# 8      https://www.edulix.com/share-profile/85497
# 9      https://www.edulix.com/share-profile/86456
# 10     https://www.edulix.com/share-profile/87421
# 11     https://www.edulix.com/share-profile/89467
# 12     https://www.edulix.com/share-profile/93397
# 13    https://www.edulix.com/share-profile/101376
# 14    https://www.edulix.com/share-profile/103171
# 15    https://www.edulix.com/share-profile/105929
# 16    https://www.edulix.com/share-profile/107990
# 17    https://www.edulix.com/share-profile/109798
# ...

# %%
options = Options()
ua = UserAgent()
userAgent = ua.random

options.add_argument(f'user-agent={userAgent}')
driver = webdriver.Chrome(chrome_options=options, executable_path = 'chromedriver.exe')

driver.get('https://www.edulix.com/')
time.sleep(30)
driver.get('https://www.edulix.com/' + 'share-profile/93397')
#page = requests.get("https://yocket.in/applications-admits-rejects/26228-null/2?page=" + str(i))
html = driver.page_source
soup = BeautifulSoup(html)

# %%
copy=name_containers

# %%
copy[37].text
# Out:
# 'Masters'

# %%
records = [["username","firstname","undergrad_college","undergrad_major","undergrad_gpa","country","gre_quant","gre_verbal","gre_awa","toefl_list","toefl_spk","toefl_rd","toefl_wrt","ielts_list","ielts_spk","ielts_rd","program","university","major","term","year","status"]]

# %%
username = copy[0].text
firstname = copy[1].text
undergrad_college = copy[8].text
undergrad_major = copy[9].text
undergrad_gpa = copy[10].text
country = copy[11].text
gre_quant = copy[12].text
gre_verbal = copy[13].text
gre_total = gre_quant+gre_verbal
gre_awa = copy[14].text
toefl_list = copy[16].text
toefl_spk = copy[17].text
toefl_rd = copy[18].text
toefl_wrt = copy[19].text
ielts_list = copy[21].text
ielts_spk = copy[22].text
ielts_rd = copy[23].text
ielts_wrt = copy[24].text
program = copy[31].text
university = copy[32].text
major = copy[33].text
term = copy[34].text
year = copy[35].text
status = copy[36].text
records.append([username,firstname,undergrad_college,undergrad_major,undergrad_gpa,country,gre_quant,gre_verbal,gre_awa,toefl_list,toefl_spk,toefl_rd,toefl_wrt,ielts_list,ielts_spk,ielts_rd,program,university,major,term,year,status])

# %%
copy[42+6]
# Out:
# <p class="form-control-static">Rejected</p>

# %%
for i in range(0,len(copy[37:]),6):
    username = copy[0].text
    firstname = copy[1].text
    undergrad_college = copy[8].text
    undergrad_major = copy[9].text
    undergrad_gpa = copy[10].text
    country = copy[11].text
    gre_quant = copy[12].text
    gre_verbal = copy[13].text
    gre_awa = copy[14].text
    toefl_list = copy[16].text
    toefl_spk = copy[17].text
    toefl_rd = copy[18].text
    toefl_wrt = copy[19].text
    ielts_list = copy[21].text
    ielts_spk = copy[22].text
    ielts_rd = copy[23].text
    ielts_wrt = copy[24].text
    program = copy[37+i].text
    university = copy[38+i].text
    major = copy[39+i].text
    term = copy[40+i].text
    year = copy[41+i].text
    status = copy[42+i].text
    records.append([username,firstname,undergrad_college,undergrad_major,undergrad_gpa,country,gre_quant,gre_verbal,gre_awa,toefl_list,toefl_spk,toefl_rd,toefl_wrt,ielts_list,ielts_spk,ielts_rd,program,university,major,term,year,status])

# %%
records
# Out:
# [['username',
#   'firstname',
#   'undergrad_college',
#   'undergrad_major',
#   'undergrad_gpa',
#   'country',
#   'gre_quant',
#   'gre_verbal',
#   'gre_awa',
#   'toefl_list',
#   'toefl_spk',
#   'toefl_rd',
#   'toefl_wrt',
#   'ielts_list',
#   'ielts_spk',
#   'ielts_rd',
#   'program',
#   'university',
#   'major',
#   'term',
#   'year',
#   'status']]

# %%
df = pd.DataFrame(records[1:],columns=records[0])

# %%
df
# Out:
#       username firstname undergrad_college   undergrad_major undergrad_gpa  \
# 0  girishpatni    Girish         NIT Patna  Computer Science       8.24/10
# 1  girishpatni    Girish         NIT Patna  Computer Science       8.24/10
# 2  girishpatni    Girish         NIT Patna  Computer Science       8.24/10
# 3  girishpatni    Girish         NIT Patna  Computer Science       8.24/10
# 4  girishpatni    Girish         NIT Patna  Computer Science       8.24/10
# 5  girishpatni    Girish         NIT Patna  Computer Science       8.24/10
# 6  girishpatni    Girish         NIT Patna  Computer Science       8.24/10
# 7  girishpatni    Girish         NIT Patna  Computer Science       8.24/10
# 8  girishpatni    Girish         NIT Patna  Computer Science       8.24/10
#
#   country gre_quant gre_verbal gre_awa toefl_list    ...    toefl_wrt  \
# 0          167 /170  155 / 170   4 / 6     0 / 30    ...       0 / 30
# 1          167 /170  155 / 170   4 / 6     0 / 30    ...       0 / 30
# ...

# %%
def scrape_admissions_data(profile_urls):
    count=0
    options = Options()
    ua = UserAgent()
    userAgent = ua.random
    options.add_argument(f'user-agent={userAgent}')
    driver = webdriver.Chrome(chrome_options=options, executable_path = 'chromedriver.exe')
    driver.get('https://www.edulix.com/auth/login')
    time.sleep(25)
    for each in profile_urls['profiles'].tolist():
        try:
            driver.get(each)
            #page = requests.get("https://yocket.in/applications-admits-rejects/26228-null/2?page=" + str(i))
            html = driver.page_source
            soup = BeautifulSoup(html)
            name_containers = soup.select('.form-control-static')
            copy=name_containers
            username = copy[0].text
            firstname = copy[1].text
            undergrad_college = copy[8].text
            undergrad_major = copy[9].text
            undergrad_gpa = copy[10].text
            country = copy[11].text
            gre_quant = copy[12].text
            gre_verbal = copy[13].text
            gre_total = gre_quant+gre_verbal
            gre_awa = copy[14].text
            toefl_list = copy[16].text
            toefl_spk = copy[17].text
            toefl_rd = copy[18].text
            toefl_wrt = copy[19].text
            ielts_list = copy[21].text
            ielts_spk = copy[22].text
            ielts_rd = copy[23].text
            ielts_wrt = copy[24].text
            program = copy[31].text
            university = copy[32].text
            major = copy[33].text
            term = copy[34].text
            year = copy[35].text
            status = copy[36].text
            records.append([username,firstname,undergrad_college,undergrad_major,undergrad_gpa,country,gre_quant,gre_verbal,gre_awa,toefl_list,toefl_spk,toefl_rd,toefl_wrt,ielts_list,ielts_spk,ielts_rd,program,university,major,term,year,status])
            count+=1
            print('records generated: '+str(count))
        except:
            continue
        for i in range(0,len(copy[37:]),6):
            try:
                username = copy[0].text
                firstname = copy[1].text
                undergrad_college = copy[8].text
                undergrad_major = copy[9].text
                undergrad_gpa = copy[10].text
                country = copy[11].text
                gre_quant = copy[12].text
                gre_verbal = copy[13].text
                gre_awa = copy[14].text
                toefl_list = copy[16].text
                toefl_spk = copy[17].text
                toefl_rd = copy[18].text
                toefl_wrt = copy[19].text
                ielts_list = copy[21].text
                ielts_spk = copy[22].text
                ielts_rd = copy[23].text
                ielts_wrt = copy[24].text
                program = copy[37+i].text
                university = copy[38+i].text
                major = copy[39+i].text
                term = copy[40+i].text
                year = copy[41+i].text
                status = copy[42+i].text
                records.append([username,firstname,undergrad_college,undergrad_major,undergrad_gpa,country,gre_quant,gre_verbal,gre_awa,toefl_list,toefl_spk,toefl_rd,toefl_wrt,ielts_list,ielts_spk,ielts_rd,program,university,major,term,year,status])
                count+=1
                print('records generated: '+str(count))
            except:
                continue

# %%
scrape_admissions_data(total_profiles_urls)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: use options instead of chrome_options
#   import sys
# records generated: 1
# records generated: 2
# records generated: 3
# records generated: 4
# records generated: 5
# records generated: 6
# records generated: 7
# records generated: 8
# records generated: 9
# records generated: 10
# records generated: 11
# records generated: 12
# records generated: 13
# records generated: 14
# records generated: 15
# records generated: 16
# records generated: 17
# records generated: 18
# records generated: 19
# records generated: 20
# records generated: 21
# records generated: 22
# records generated: 23
# records generated: 24
# records generated: 25
# records generated: 26
# records generated: 27
# records generated: 28
# records generated: 29
# records generated: 30
# records generated: 31
# records generated: 32
# records generated: 33
# records generated: 34
# records generated: 35
# records generated: 36
# ...

# %%
admission_records['major'].unique()
# Out:
# array(['Mechanical Engineering', 'MIS', 'Computer Science',
#        'Electronics and Communication', 'Computer Engineering',
#        'CS / MSIS / ITM', 'Telecommunication', 'Industrial Engineering',
#        'Engineering Management', 'Comp Science/Comp Networks/Comp Engg',
#        'Manufacturing Engineering', 'Computer Networking',
#        'Information Security', 'MIS-management related courses',
#        'Industrial Engg/Robotics', 'MIS/CS', 'Telecom management ', '',
#        'Information Systems', 'Electrical Engineering', 'MEM', 'CS',
#        'Electronic and Telecommunication Engineering',
#        'Civil Engineering', '(MIS / MSIM / MSIS / MSIT)', 'Information',
#        'Computer Networks', 'Management Information System',
#        'medicinal chemistry', 'Information Science',
#        'Information Assurance',
#        'Electrical and computer engineering, electrical engineering, telecommunications engineering',
#        'India', 'Health Informatics', 'Biotechnology',
# ...

# %%
admission_records = pd.DataFrame(records[1:],columns=records[0])

# %%
admission_records.loc[admission_records['university']=='Northeastern University',:]['status'].value_counts()
# Out:
# Admitted    660
# Applied     262
# Rejected    253
# Name: status, dtype: int64

# %%
admission_records.to_csv('.\data\Edulix_admission_records.csv')

# %%
admission_records.drop_duplicates(inplace=True)

# %%
admission_records.reset_index(drop=True,inplace=True)

# %%
colleges = admission_records.university.tolist()

# %%
required_colleges = ['Northeastern University','Illinois Institute of Technology','Michigan Technological University','Rochester Institute of Technology','University of Southern California','University of North Carolina Charlotte','University of Texas Arlington','University of Texas Dallas','Syracuse University','Clemson University','New York University','Indiana University-Bloomington','Rutgers University New Brunswick/Piscataway','San Jose State University','University of Florida']

# %%
adm = pd.DataFrame()
for college in colleges:
    print(college)
    boolean = (admission_records['university']== college) & ((admission_records['major'] == 'Computer Science') | (admission_records['major'] == 'CS'))
    print(admission_records.loc[boolean,:]['status'].value_counts())
    print('===========================================================================================')
# Out:
# North Carolina State University
# Rejected    292
# Admitted    166
# Applied      82
# Name: status, dtype: int64
# ...
# University of North Carolina Charlotte
# Admitted    114
# Rejected     79
# Applied      27
# Name: status, dtype: int64
# ...
# University of Arizona
# Rejected    34
# Admitted     8
# Applied      4
# Name: status, dtype: int64
# ...
# University of Maryland College Park
# Rejected    56
# Applied      5
# Admitted     2
# Name: status, dtype: int64
# ...
# University of Texas Austin
# Rejected    77
# Applied     13
# Admitted     4
# Name: status, dtype: int64
# ...
# Texas A and M University College Station
# Rejected    136
# Applied     112
# Admitted     28
# Name: status, dtype: int64
# ...
# Georgia Institute of Technology
# Rejected    216
# Applied      39
# Admitted     13
# Name: status, dtype: int64
# ...
# University of Utah
# Rejected    79
# Admitted    35
# Applied     28
# Name: status, dtype: int64
# ...
# Northeastern University
# Admitted    316
# Rejected    164
# Applied     112
# ...

# %%
adm = pd.DataFrame()
for college in required_colleges:
    print(college)
    boolean = (admission_records['university']== college) & ((admission_records['major'] == 'Computer Science') | (admission_records['major'] == 'CS'))
    print(admission_records.loc[boolean,:]['status'].value_counts())
    print('===========================================================================================')
# Out:
# Northeastern University
# Admitted    316
# Rejected    164
# Applied     112
# Name: status, dtype: int64
# ...
# Illinois Institute of Technology
# Admitted    116
# Rejected     24
# Applied      12
# Name: status, dtype: int64
# ...
# Michigan Technological University
# Admitted    10
# Rejected     5
# Applied      1
# Name: status, dtype: int64
# ...
# Rochester Institute of Technology
# Admitted    233
# Applied      18
# Rejected      8
# Name: status, dtype: int64
# ...
# University of Southern California
# Applied     286
# Admitted    259
# Rejected    117
# Name: status, dtype: int64
# ...
# University of North Carolina Charlotte
# Admitted    114
# Rejected     79
# Applied      27
# Name: status, dtype: int64
# ...
# University of Texas Arlington
# Admitted    140
# Applied      29
# Rejected     25
# Name: status, dtype: int64
# ...
# University of Texas Dallas
# Admitted    495
# Rejected    151
# Applied      49
# Name: status, dtype: int64
# ...
# Syracuse University
# Admitted    122
# Rejected     95
# ...

# %%
admission_records=admission_records.loc[admission_records['undergrad_college']!="0 / 30",:]

# %%
admission_records.groupby(by=['university'])['status'].value_counts(
# Out:
# university                                    status
# 0000-00-00 00:00:00                           Fall                                   1
# 01/2016                                       2016-01-01 05:00:00                    1
# 06/2018                                       Research Fellow                        1
# 10/2018                                       2016-06-01 05:00:00                    1
# 2013                                          Engineering Management                 3
# 2015-12-01 05:00:00                           India                                  1
# 2016                                          Aerospace Engineering                  2
#                                               05/2017                                1
# 2016-07-01 00:00:00                           2015-06-01 00:00:00                    1
# 2017-07-01 00:00:00                           India                                  1
# ...

# %%
admission_records=admission_records.loc[(admission_records['status']=='Applied') | (admission_records['status']=='Admitted') |(admission_records['status']=='Rejected'),: ]

# %%
copy = admission_records.loc[admission_records["major"].str.contains("computer science",case=False)|admission_records["major"].str.contains("CS",case=True) | admission_records["major"].str.contains("Comp Science",case=False),:]

# %%
copy['ielts_list'].value_counts()
# Out:
# 0 / 9               12697
# CS                     11
# Computer Science        6
# Name: ielts_list, dtype: int64

# %%
copy['year'].value_counts()
# Out:
# 2013    4109
# 2014    3939
# 2015    2619
# 2016    1549
# 2017     474
# 2018      24
# Name: year, dtype: int64

# %% [markdown]
# <b> Edulix : CSV file  </b>

# %%
Edulix_Reject_data_all_college = pd.read_csv(r'data\Edulix_admission_records.csv')

# %%
Edulix_Reject_data_all_college.columns.values
# Out:
# array(['Unnamed: 0', 'username', 'firstname', 'undergrad_college',
#        'undergrad_major', 'undergrad_gpa', 'country', 'gre_quant',
#        'gre_verbal', 'gre_awa', 'toefl_list', 'toefl_spk', 'toefl_rd',
#        'toefl_wrt', 'ielts_list', 'ielts_spk', 'ielts_rd', 'program',
#        'university', 'major', 'term', 'year', 'status'], dtype=object)

# %%
Edulix_Reject_data_all_college
# Out:
#        Unnamed: 0        username                firstname  \
# 0               1     pranayvanja             Pranay Vanja
# 1               2     pranayvanja             Pranay Vanja
# 2               3     pranayvanja             Pranay Vanja
# 3               4     pranayvanja             Pranay Vanja
# 4               5     pranayvanja             Pranay Vanja
# 5               6     pranayvanja             Pranay Vanja
# 6               7     ashwath1993          Ashwath Narayan
# 7               8     ashwath1993          Ashwath Narayan
# 8               9     ashwath1993          Ashwath Narayan
# 9              10     ashwath1993          Ashwath Narayan
# 10             11     ashwath1993          Ashwath Narayan
# 11             12     ashwath1993          Ashwath Narayan
# 12             13     ashwath1993          Ashwath Narayan
# 13             14     ashwath1993          Ashwath Narayan
# 14             15     ashwath1993          Ashwath Narayan
# ...
